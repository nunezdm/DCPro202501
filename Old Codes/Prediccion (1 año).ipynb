# %% [markdown]
# # Cargar

# %% [markdown]
# ## Biblioteca

# %%
import optuna
import pandas as pd  # load and manipulate data and for One-Hot Encoding
import numpy as np  # calculate the mean and standard deviation
import seaborn as sns
import matplotlib.pyplot as plt
import xgboost as xgb  # XGBoost stuff
from sklearn.model_selection import train_test_split  # split data into training and testing sets
from sklearn.metrics import balanced_accuracy_score, roc_auc_score, make_scorer  # for scoring during
from sklearn.model_selection import GridSearchCV  # cross validation
from sklearn.metrics import confusion_matrix  # creates a confusion matrix
from sklearn.metrics import ConfusionMatrixDisplay  # draws a confusion matrix
from sklearn.preprocessing import OneHotEncoder  # Más explícito para encoding
from sklearn.metrics import classification_report

from joblib import Parallel, delayed
from tqdm import tqdm
from datetime import timedelta
from sklearn.preprocessing import LabelEncoder, StandardScaler
from xgboost import XGBRegressor
from xgboost import XGBClassifier
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.model_selection import RandomizedSearchCV
from xgboost import plot_importance
from itertools import product

# %% [markdown]
# ## Data Frame

# %%
df_base = pd.read_csv('base_rm.csv', encoding='utf-8', low_memory=False)
df_base = df_base.reset_index(drop=True)
df_base['Date'] = pd.to_datetime(df_base['Date'])

df_base = df_base.sort_values('Date')

filas, columnas = df_base.shape
print(f"Número de filas: {filas}")
print(f"Número de columnas: {columnas}")
# Out:
# Número de filas: 9984660
# Número de columnas: 18

# %%
df_base.head()
# Out:
#               Date  Year  Month  Day  Hour Nombre_Oficina_Arp  \
# 7521029 2019-01-01  2019      1    1     0     OFICINA BOGOTA
# 6131996 2019-01-01  2019      1    1     0       OFICINA CALI
# 6131995 2019-01-01  2019      1    1     0   OFICINA MEDELLIN
# 8925611 2019-01-01  2019      1    1     0    OFICINA PEREIRA
# 8925610 2019-01-01  2019      1    1     0  OFICINA MANIZALES
#
#         Nombre_Municipio_IPS2          MUNICIPIO Nombre_Tipo_Atencion_Arp  \
# 7521029              MEDELLIN              FUNZA  QUIRURGICO HOSPITALARIO
# 6131996              MEDELLIN            PRADERA   QUIRURGICO AMBULATORIO
# 6131995              MEDELLIN           MEDELLIN   QUIRURGICO AMBULATORIO
# 8925611               PEREIRA  PEREIRA-RISARALDA  QUIRURGICO HOSPITALARIO
# 8925610               PEREIRA            MARMATO  QUIRURGICO HOSPITALARIO
#
#          Cantidad  TENDENCIA  lag_1  lag_7  mm_7  mm_12  mm_30  delta_lag  \
# 7521029         1          0    NaN    NaN   NaN    NaN    NaN        NaN
# 6131996         1          0    1.0    NaN   NaN    NaN    NaN        0.0
# 6131995         1          0    NaN    NaN   NaN    NaN    NaN        NaN
# 8925611         1          0    1.0    NaN   NaN    NaN    NaN        0.0
# 8925610         1          0    NaN    NaN   NaN    NaN    NaN        NaN
#
#          std_7
# 7521029    NaN
# 6131996    NaN
# 6131995    NaN
# 8925611    NaN
# 8925610    NaN

# %% [markdown]
# # Formato

# %% [markdown]
# ## Encoded

# %%
df_encoded_base = pd.get_dummies(df_base, columns=['Nombre_Oficina_Arp', 'Nombre_Tipo_Atencion_Arp'])

lip = LabelEncoder()
lm = LabelEncoder()

df_encoded_base['Nombre_Municipio_IPS2'] = lip.fit_transform(df_base['Nombre_Municipio_IPS2'])
df_encoded_base['MUNICIPIO'] = lm.fit_transform(df_base['MUNICIPIO'])

municipio_ips_dict = dict(zip(lip.transform(lip.classes_), lip.classes_))
municipio_dict = dict(zip(lm.transform(lm.classes_), lm.classes_))

df_encoded_base.head()
# Out:
#               Date  Year  Month  Day  Hour  Nombre_Municipio_IPS2  MUNICIPIO  \
# 7521029 2019-01-01  2019      1    1     0                     80        354
# 6131996 2019-01-01  2019      1    1     0                     80        684
# 6131995 2019-01-01  2019      1    1     0                     80        547
# 8925611 2019-01-01  2019      1    1     0                     97        659
# 8925610 2019-01-01  2019      1    1     0                     97        542
#
#          Cantidad  TENDENCIA  lag_1  ...  \
# 7521029         1          0    NaN  ...
# 6131996         1          0    1.0  ...
# 6131995         1          0    NaN  ...
# 8925611         1          0    1.0  ...
# 8925610         1          0    NaN  ...
#
#          Nombre_Oficina_Arp_OFICINA MANIZALES  \
# 7521029                                 False
# 6131996                                 False
# 6131995                                 False
# 8925611                                 False
# 8925610                                  True
#
#          Nombre_Oficina_Arp_OFICINA MEDELLIN  \
# 7521029                                False
# 6131996                                False
# 6131995                                 True
# 8925611                                False
# 8925610                                False
#
#          Nombre_Oficina_Arp_OFICINA PEREIRA  \
# 7521029                               False
# 6131996                               False
# 6131995                               False
# 8925611                                True
# 8925610                               False
#
#          Nombre_Tipo_Atencion_Arp_ALTA INMEDIATA  \
# 7521029                                    False
# 6131996                                    False
# 6131995                                    False
# 8925611                                    False
# 8925610                                    False
#
#          Nombre_Tipo_Atencion_Arp_AMBULATORIA  \
# 7521029                                 False
# 6131996                                 False
# 6131995                                 False
# 8925611                                 False
# 8925610                                 False
#
#          Nombre_Tipo_Atencion_Arp_HOSPITALARIA  \
# 7521029                                  False
# 6131996                                  False
# 6131995                                  False
# 8925611                                  False
# 8925610                                  False
#
#          Nombre_Tipo_Atencion_Arp_ODONTOLOGIA  \
# 7521029                                 False
# 6131996                                 False
# 6131995                                 False
# 8925611                                 False
# 8925610                                 False
#
#          Nombre_Tipo_Atencion_Arp_QUIRURGICO AMBULATORIO  \
# 7521029                                            False
# 6131996                                             True
# 6131995                                             True
# 8925611                                            False
# 8925610                                            False
#
#          Nombre_Tipo_Atencion_Arp_QUIRURGICO HOSPITALARIO  \
# 7521029                                              True
# 6131996                                             False
# 6131995                                             False
# 8925611                                              True
# 8925610                                              True
#
#          Nombre_Tipo_Atencion_Arp_UNIDAD DE CUIDADOS INTENSIVOS
# 7521029                                              False
# 6131996                                              False
# 6131995                                              False
# 8925611                                              False
# 8925610                                              False
#
# [5 rows x 31 columns]

# %% [markdown]
# ## Division

# %%
df_encoded_base.tail(1)
# Out:
#                        Date  Year  Month  Day  Hour  Nombre_Municipio_IPS2  \
# 1551507 2024-12-31 22:35:00  2024     12   31    22                     15
#
#          MUNICIPIO  Cantidad  TENDENCIA  lag_1  ...  \
# 1551507        547         1      52606    1.0  ...
#
#          Nombre_Oficina_Arp_OFICINA MANIZALES  \
# 1551507                                 False
#
#          Nombre_Oficina_Arp_OFICINA MEDELLIN  \
# 1551507                                 True
#
#          Nombre_Oficina_Arp_OFICINA PEREIRA  \
# 1551507                               False
#
#          Nombre_Tipo_Atencion_Arp_ALTA INMEDIATA  \
# 1551507                                    False
#
#          Nombre_Tipo_Atencion_Arp_AMBULATORIA  \
# 1551507                                 False
#
#          Nombre_Tipo_Atencion_Arp_HOSPITALARIA  \
# 1551507                                  False
#
#          Nombre_Tipo_Atencion_Arp_ODONTOLOGIA  \
# 1551507                                 False
#
#          Nombre_Tipo_Atencion_Arp_QUIRURGICO AMBULATORIO  \
# 1551507                                            False
#
#          Nombre_Tipo_Atencion_Arp_QUIRURGICO HOSPITALARIO  \
# 1551507                                              True
#
#          Nombre_Tipo_Atencion_Arp_UNIDAD DE CUIDADOS INTENSIVOS
# 1551507                                              False
#
# [1 rows x 31 columns]

# %%
df_encoded_base.dtypes
# Out:
# Date                                                      datetime64[ns]
# Year                                                               int64
# Month                                                              int64
# Day                                                                int64
# Hour                                                               int64
# Nombre_Municipio_IPS2                                              int32
# MUNICIPIO                                                          int32
# Cantidad                                                           int64
# TENDENCIA                                                          int64
# lag_1                                                            float64
# lag_7                                                            float64
# mm_7                                                             float64
# mm_12                                                            float64
# mm_30                                                            float64
# delta_lag                                                        float64
# std_7                                                            float64
# Nombre_Oficina_Arp_OFICINA BARRANQUILLA                             bool
# Nombre_Oficina_Arp_OFICINA BOGOTA                                   bool
# Nombre_Oficina_Arp_OFICINA BUCARAMANGA                              bool
# Nombre_Oficina_Arp_OFICINA CALI                                     bool
# Nombre_Oficina_Arp_OFICINA CARTAGENA                                bool
# Nombre_Oficina_Arp_OFICINA MANIZALES                                bool
# Nombre_Oficina_Arp_OFICINA MEDELLIN                                 bool
# Nombre_Oficina_Arp_OFICINA PEREIRA                                  bool
# Nombre_Tipo_Atencion_Arp_ALTA INMEDIATA                             bool
# Nombre_Tipo_Atencion_Arp_AMBULATORIA                                bool
# Nombre_Tipo_Atencion_Arp_HOSPITALARIA                               bool
# Nombre_Tipo_Atencion_Arp_ODONTOLOGIA                                bool
# Nombre_Tipo_Atencion_Arp_QUIRURGICO AMBULATORIO                     bool
# Nombre_Tipo_Atencion_Arp_QUIRURGICO HOSPITALARIO                    bool
# Nombre_Tipo_Atencion_Arp_UNIDAD DE CUIDADOS INTENSIVOS              bool
# dtype: object

# %%
#Dividir datos
cutoff = pd.to_datetime('2024-12-31')
train = df_encoded_base[df_encoded_base['Date'] <= cutoff]

X_train = train.drop(columns=['Date', 'Cantidad'])
y_train = train['Cantidad']

features = X_train.columns.tolist()

#Estructura DMatrix
dtrain = xgb.DMatrix(X_train, label=y_train)

print("X shape:", df_encoded_base.shape)

print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
# Out:
# X shape: (9984660, 31)
# X_train shape: (9982042, 29)
# y_train shape: (9982042,)

# %%
X_train.dtypes
# Out:
# Year                                                        int64
# Month                                                       int64
# Day                                                         int64
# Hour                                                        int64
# Nombre_Municipio_IPS2                                       int32
# MUNICIPIO                                                   int32
# TENDENCIA                                                   int64
# lag_1                                                     float64
# lag_7                                                     float64
# mm_7                                                      float64
# mm_12                                                     float64
# mm_30                                                     float64
# delta_lag                                                 float64
# std_7                                                     float64
# Nombre_Oficina_Arp_OFICINA BARRANQUILLA                      bool
# Nombre_Oficina_Arp_OFICINA BOGOTA                            bool
# Nombre_Oficina_Arp_OFICINA BUCARAMANGA                       bool
# Nombre_Oficina_Arp_OFICINA CALI                              bool
# Nombre_Oficina_Arp_OFICINA CARTAGENA                         bool
# Nombre_Oficina_Arp_OFICINA MANIZALES                         bool
# Nombre_Oficina_Arp_OFICINA MEDELLIN                          bool
# Nombre_Oficina_Arp_OFICINA PEREIRA                           bool
# Nombre_Tipo_Atencion_Arp_ALTA INMEDIATA                      bool
# Nombre_Tipo_Atencion_Arp_AMBULATORIA                         bool
# Nombre_Tipo_Atencion_Arp_HOSPITALARIA                        bool
# Nombre_Tipo_Atencion_Arp_ODONTOLOGIA                         bool
# Nombre_Tipo_Atencion_Arp_QUIRURGICO AMBULATORIO              bool
# Nombre_Tipo_Atencion_Arp_QUIRURGICO HOSPITALARIO             bool
# Nombre_Tipo_Atencion_Arp_UNIDAD DE CUIDADOS INTENSIVOS       bool
# dtype: object

# %% [markdown]
# ## Modelo

# %%
best_params = {'learning_rate': 0.1041632522057729, 
               'max_depth': 6, 
               'subsample': 0.9506239437939494, 
               'colsample_bytree': 0.9832575009920059, 
               'gamma': 0.009185962608650233, 
               'lambda': 0.7695030088742605, 
               'alpha': 0.0020379600947978494, 
               'n_estimators': 396}

params = {
    'objective': 'reg:squarederror',
    'tree_method': 'gpu_hist',  # o 'hist' si estás en CPU
    'predictor': 'gpu_predictor',
    'learning_rate': best_params['learning_rate'],
    'max_depth': best_params['max_depth'],
    'subsample': best_params['subsample'],
    'colsample_bytree': best_params['colsample_bytree'],
    'gamma': best_params['gamma'],
    'lambda': best_params['lambda'],
    'alpha': best_params['alpha'],
    'eval_metric': 'rmse'
}

model = xgb.train(
    params=params,
    dtrain=dtrain,
    num_boost_round=best_params['n_estimators'],  # ¡Importante!
    evals=[(dtrain, 'Train')],
    early_stopping_rounds=20,
    verbose_eval=True
)
# Out:
# c:\Users\humbe\anaconda3\Lib\site-packages\xgboost\core.py:160: UserWarning: [17:17:33] WARNING: D:\bld\xgboost-split_1703076510930\work\src\common\error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\humbe\anaconda3\Lib\site-packages\xgboost\core.py:160: UserWarning: [17:17:33] WARNING: D:\bld\xgboost-split_1703076510930\work\src\learner.cc:742:
# Parameters: { "predictor" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [0]	Train-rmse:1.63964
# [1]	Train-rmse:1.47020
# [2]	Train-rmse:1.31856
# [3]	Train-rmse:1.18282
# [4]	Train-rmse:1.06138
# [5]	Train-rmse:0.95279
# [6]	Train-rmse:0.85563
# [7]	Train-rmse:0.76885
# [8]	Train-rmse:0.69122
# [9]	Train-rmse:0.62977
# [10]	Train-rmse:0.56727
# [11]	Train-rmse:0.51149
# [12]	Train-rmse:0.46186
# [13]	Train-rmse:0.41758
# [14]	Train-rmse:0.37816
# [15]	Train-rmse:0.34331
# [16]	Train-rmse:0.31259
# [17]	Train-rmse:0.28541
# [18]	Train-rmse:0.26087
# [19]	Train-rmse:0.23986
# [20]	Train-rmse:0.22347
# [21]	Train-rmse:0.20705
# [22]	Train-rmse:0.19279
# [23]	Train-rmse:0.18050
# [24]	Train-rmse:0.16945
# [25]	Train-rmse:0.15945
# [26]	Train-rmse:0.15158
# [27]	Train-rmse:0.15112
# [28]	Train-rmse:0.14412
# [29]	Train-rmse:0.13759
# [30]	Train-rmse:0.13248
# [31]	Train-rmse:0.12832
# [32]	Train-rmse:0.12438
# [33]	Train-rmse:0.12127
# [34]	Train-rmse:0.11769
# [35]	Train-rmse:0.11519
# [36]	Train-rmse:0.11317
# [37]	Train-rmse:0.11296
# [38]	Train-rmse:0.11060
# [39]	Train-rmse:0.10852
# [40]	Train-rmse:0.10677
# [41]	Train-rmse:0.10537
# [42]	Train-rmse:0.10433
# [43]	Train-rmse:0.10311
# [44]	Train-rmse:0.10191
# [45]	Train-rmse:0.10088
# [46]	Train-rmse:0.10003
# [47]	Train-rmse:0.09907
# [48]	Train-rmse:0.09840
# [49]	Train-rmse:0.09783
# [50]	Train-rmse:0.09743
# [51]	Train-rmse:0.09685
# [52]	Train-rmse:0.09591
# [53]	Train-rmse:0.09569
# [54]	Train-rmse:0.09521
# [55]	Train-rmse:0.09493
# [56]	Train-rmse:0.09369
# [57]	Train-rmse:0.09333
# [58]	Train-rmse:0.09325
# [59]	Train-rmse:0.09267
# [60]	Train-rmse:0.09241
# [61]	Train-rmse:0.09220
# [62]	Train-rmse:0.09193
# [63]	Train-rmse:0.09145
# [64]	Train-rmse:0.09115
# [65]	Train-rmse:0.09074
# [66]	Train-rmse:0.08964
# [67]	Train-rmse:0.08949
# [68]	Train-rmse:0.08922
# [69]	Train-rmse:0.08773
# [70]	Train-rmse:0.08709
# [71]	Train-rmse:0.08686
# [72]	Train-rmse:0.08668
# [73]	Train-rmse:0.08641
# [74]	Train-rmse:0.08617
# [75]	Train-rmse:0.08585
# [76]	Train-rmse:0.08576
# [77]	Train-rmse:0.08565
# [78]	Train-rmse:0.08539
# [79]	Train-rmse:0.08510
# [80]	Train-rmse:0.08385
# [81]	Train-rmse:0.08288
# [82]	Train-rmse:0.08140
# [83]	Train-rmse:0.08129
# [84]	Train-rmse:0.08118
# [85]	Train-rmse:0.08089
# [86]	Train-rmse:0.08086
# [87]	Train-rmse:0.08081
# [88]	Train-rmse:0.08070
# [89]	Train-rmse:0.08050
# [90]	Train-rmse:0.08034
# [91]	Train-rmse:0.07940
# [92]	Train-rmse:0.07822
# [93]	Train-rmse:0.07813
# [94]	Train-rmse:0.07784
# [95]	Train-rmse:0.07773
# [96]	Train-rmse:0.07765
# [97]	Train-rmse:0.07751
# [98]	Train-rmse:0.07667
# [99]	Train-rmse:0.07544
# [100]	Train-rmse:0.07446
# [101]	Train-rmse:0.07359
# [102]	Train-rmse:0.07321
# [103]	Train-rmse:0.07311
# [104]	Train-rmse:0.07270
# [105]	Train-rmse:0.07263
# [106]	Train-rmse:0.07249
# [107]	Train-rmse:0.07164
# [108]	Train-rmse:0.07082
# [109]	Train-rmse:0.07072
# [110]	Train-rmse:0.07023
# [111]	Train-rmse:0.07014
# [112]	Train-rmse:0.06936
# [113]	Train-rmse:0.06933
# [114]	Train-rmse:0.06878
# [115]	Train-rmse:0.06864
# [116]	Train-rmse:0.06790
# [117]	Train-rmse:0.06784
# [118]	Train-rmse:0.06777
# [119]	Train-rmse:0.06759
# [120]	Train-rmse:0.06675
# [121]	Train-rmse:0.06665
# [122]	Train-rmse:0.06624
# [123]	Train-rmse:0.06581
# [124]	Train-rmse:0.06581
# [125]	Train-rmse:0.06564
# [126]	Train-rmse:0.06435
# [127]	Train-rmse:0.06382
# [128]	Train-rmse:0.06378
# [129]	Train-rmse:0.06323
# [130]	Train-rmse:0.06291
# [131]	Train-rmse:0.06282
# [132]	Train-rmse:0.06254
# [133]	Train-rmse:0.06243
# [134]	Train-rmse:0.06237
# [135]	Train-rmse:0.06187
# [136]	Train-rmse:0.06158
# [137]	Train-rmse:0.06095
# [138]	Train-rmse:0.06094
# [139]	Train-rmse:0.06067
# [140]	Train-rmse:0.05985
# [141]	Train-rmse:0.05917
# [142]	Train-rmse:0.05887
# [143]	Train-rmse:0.05857
# [144]	Train-rmse:0.05816
# [145]	Train-rmse:0.05770
# [146]	Train-rmse:0.05736
# [147]	Train-rmse:0.05698
# [148]	Train-rmse:0.05655
# [149]	Train-rmse:0.05638
# [150]	Train-rmse:0.05586
# [151]	Train-rmse:0.05538
# [152]	Train-rmse:0.05488
# [153]	Train-rmse:0.05419
# [154]	Train-rmse:0.05368
# [155]	Train-rmse:0.05360
# [156]	Train-rmse:0.05353
# [157]	Train-rmse:0.05339
# [158]	Train-rmse:0.05297
# [159]	Train-rmse:0.05292
# [160]	Train-rmse:0.05285
# [161]	Train-rmse:0.05240
# [162]	Train-rmse:0.05198
# [163]	Train-rmse:0.05149
# [164]	Train-rmse:0.05082
# [165]	Train-rmse:0.05071
# [166]	Train-rmse:0.05032
# [167]	Train-rmse:0.05016
# [168]	Train-rmse:0.05003
# [169]	Train-rmse:0.04969
# [170]	Train-rmse:0.04921
# [171]	Train-rmse:0.04898
# [172]	Train-rmse:0.04867
# [173]	Train-rmse:0.04839
# [174]	Train-rmse:0.04834
# [175]	Train-rmse:0.04828
# [176]	Train-rmse:0.04818
# [177]	Train-rmse:0.04814
# [178]	Train-rmse:0.04813
# [179]	Train-rmse:0.04771
# [180]	Train-rmse:0.04724
# [181]	Train-rmse:0.04692
# [182]	Train-rmse:0.04680
# [183]	Train-rmse:0.04637
# [184]	Train-rmse:0.04629
# [185]	Train-rmse:0.04605
# [186]	Train-rmse:0.04567
# [187]	Train-rmse:0.04528
# [188]	Train-rmse:0.04492
# [189]	Train-rmse:0.04479
# [190]	Train-rmse:0.04471
# [191]	Train-rmse:0.04466
# [192]	Train-rmse:0.04450
# [193]	Train-rmse:0.04419
# [194]	Train-rmse:0.04397
# [195]	Train-rmse:0.04393
# [196]	Train-rmse:0.04384
# [197]	Train-rmse:0.04356
# [198]	Train-rmse:0.04350
# [199]	Train-rmse:0.04341
# [200]	Train-rmse:0.04329
# [201]	Train-rmse:0.04317
# [202]	Train-rmse:0.04278
# [203]	Train-rmse:0.04244
# [204]	Train-rmse:0.04217
# [205]	Train-rmse:0.04183
# [206]	Train-rmse:0.04169
# [207]	Train-rmse:0.04157
# [208]	Train-rmse:0.04141
# [209]	Train-rmse:0.04133
# [210]	Train-rmse:0.04108
# [211]	Train-rmse:0.04082
# [212]	Train-rmse:0.04049
# [213]	Train-rmse:0.04031
# [214]	Train-rmse:0.04029
# [215]	Train-rmse:0.04020
# [216]	Train-rmse:0.04005
# [217]	Train-rmse:0.04003
# [218]	Train-rmse:0.03988
# [219]	Train-rmse:0.03984
# [220]	Train-rmse:0.03968
# [221]	Train-rmse:0.03958
# [222]	Train-rmse:0.03949
# [223]	Train-rmse:0.03934
# [224]	Train-rmse:0.03914
# [225]	Train-rmse:0.03903
# [226]	Train-rmse:0.03870
# [227]	Train-rmse:0.03865
# [228]	Train-rmse:0.03841
# [229]	Train-rmse:0.03829
# [230]	Train-rmse:0.03806
# [231]	Train-rmse:0.03786
# [232]	Train-rmse:0.03759
# [233]	Train-rmse:0.03748
# [234]	Train-rmse:0.03741
# [235]	Train-rmse:0.03730
# [236]	Train-rmse:0.03728
# [237]	Train-rmse:0.03709
# [238]	Train-rmse:0.03693
# [239]	Train-rmse:0.03690
# [240]	Train-rmse:0.03675
# [241]	Train-rmse:0.03669
# [242]	Train-rmse:0.03639
# [243]	Train-rmse:0.03621
# [244]	Train-rmse:0.03616
# [245]	Train-rmse:0.03611
# [246]	Train-rmse:0.03608
# [247]	Train-rmse:0.03590
# [248]	Train-rmse:0.03580
# [249]	Train-rmse:0.03569
# [250]	Train-rmse:0.03560
# [251]	Train-rmse:0.03557
# [252]	Train-rmse:0.03548
# [253]	Train-rmse:0.03532
# [254]	Train-rmse:0.03528
# [255]	Train-rmse:0.03507
# [256]	Train-rmse:0.03496
# [257]	Train-rmse:0.03489
# [258]	Train-rmse:0.03479
# [259]	Train-rmse:0.03465
# [260]	Train-rmse:0.03460
# [261]	Train-rmse:0.03443
# [262]	Train-rmse:0.03433
# [263]	Train-rmse:0.03416
# [264]	Train-rmse:0.03402
# [265]	Train-rmse:0.03393
# [266]	Train-rmse:0.03381
# [267]	Train-rmse:0.03367
# [268]	Train-rmse:0.03366
# [269]	Train-rmse:0.03360
# [270]	Train-rmse:0.03345
# [271]	Train-rmse:0.03335
# [272]	Train-rmse:0.03311
# [273]	Train-rmse:0.03308
# [274]	Train-rmse:0.03304
# [275]	Train-rmse:0.03294
# [276]	Train-rmse:0.03283
# [277]	Train-rmse:0.03268
# [278]	Train-rmse:0.03260
# [279]	Train-rmse:0.03255
# [280]	Train-rmse:0.03241
# [281]	Train-rmse:0.03227
# [282]	Train-rmse:0.03217
# [283]	Train-rmse:0.03204
# [284]	Train-rmse:0.03189
# [285]	Train-rmse:0.03168
# [286]	Train-rmse:0.03153
# [287]	Train-rmse:0.03147
# [288]	Train-rmse:0.03139
# [289]	Train-rmse:0.03126
# [290]	Train-rmse:0.03116
# [291]	Train-rmse:0.03106
# [292]	Train-rmse:0.03091
# [293]	Train-rmse:0.03081
# [294]	Train-rmse:0.03079
# [295]	Train-rmse:0.03066
# [296]	Train-rmse:0.03052
# [297]	Train-rmse:0.03042
# [298]	Train-rmse:0.03038
# [299]	Train-rmse:0.03022
# [300]	Train-rmse:0.03012
# [301]	Train-rmse:0.02992
# [302]	Train-rmse:0.02978
# [303]	Train-rmse:0.02970
# [304]	Train-rmse:0.02963
# [305]	Train-rmse:0.02950
# [306]	Train-rmse:0.02936
# [307]	Train-rmse:0.02927
# [308]	Train-rmse:0.02917
# [309]	Train-rmse:0.02904
# [310]	Train-rmse:0.02888
# [311]	Train-rmse:0.02882
# [312]	Train-rmse:0.02873
# [313]	Train-rmse:0.02866
# [314]	Train-rmse:0.02858
# [315]	Train-rmse:0.02841
# [316]	Train-rmse:0.02825
# [317]	Train-rmse:0.02811
# [318]	Train-rmse:0.02798
# [319]	Train-rmse:0.02778
# [320]	Train-rmse:0.02769
# [321]	Train-rmse:0.02763
# [322]	Train-rmse:0.02759
# [323]	Train-rmse:0.02745
# [324]	Train-rmse:0.02735
# [325]	Train-rmse:0.02733
# [326]	Train-rmse:0.02728
# [327]	Train-rmse:0.02723
# [328]	Train-rmse:0.02710
# [329]	Train-rmse:0.02707
# [330]	Train-rmse:0.02699
# [331]	Train-rmse:0.02695
# [332]	Train-rmse:0.02684
# [333]	Train-rmse:0.02675
# [334]	Train-rmse:0.02672
# [335]	Train-rmse:0.02667
# [336]	Train-rmse:0.02659
# [337]	Train-rmse:0.02650
# [338]	Train-rmse:0.02644
# [339]	Train-rmse:0.02637
# [340]	Train-rmse:0.02625
# [341]	Train-rmse:0.02617
# [342]	Train-rmse:0.02606
# [343]	Train-rmse:0.02595
# [344]	Train-rmse:0.02584
# [345]	Train-rmse:0.02579
# [346]	Train-rmse:0.02576
# [347]	Train-rmse:0.02567
# [348]	Train-rmse:0.02560
# [349]	Train-rmse:0.02553
# [350]	Train-rmse:0.02550
# [351]	Train-rmse:0.02545
# [352]	Train-rmse:0.02542
# [353]	Train-rmse:0.02538
# [354]	Train-rmse:0.02527
# [355]	Train-rmse:0.02515
# [356]	Train-rmse:0.02509
# [357]	Train-rmse:0.02501
# [358]	Train-rmse:0.02495
# [359]	Train-rmse:0.02486
# [360]	Train-rmse:0.02482
# [361]	Train-rmse:0.02478
# [362]	Train-rmse:0.02473
# [363]	Train-rmse:0.02469
# [364]	Train-rmse:0.02466
# [365]	Train-rmse:0.02462
# [366]	Train-rmse:0.02453
# [367]	Train-rmse:0.02452
# [368]	Train-rmse:0.02444
# [369]	Train-rmse:0.02440
# [370]	Train-rmse:0.02431
# [371]	Train-rmse:0.02426
# [372]	Train-rmse:0.02413
# [373]	Train-rmse:0.02408
# [374]	Train-rmse:0.02399
# [375]	Train-rmse:0.02389
# [376]	Train-rmse:0.02382
# [377]	Train-rmse:0.02374
# [378]	Train-rmse:0.02367
# [379]	Train-rmse:0.02363
# [380]	Train-rmse:0.02354
# [381]	Train-rmse:0.02345
# [382]	Train-rmse:0.02333
# [383]	Train-rmse:0.02326
# [384]	Train-rmse:0.02317
# [385]	Train-rmse:0.02313
# [386]	Train-rmse:0.02305
# [387]	Train-rmse:0.02302
# [388]	Train-rmse:0.02293
# [389]	Train-rmse:0.02285
# [390]	Train-rmse:0.02277
# [391]	Train-rmse:0.02268
# [392]	Train-rmse:0.02261
# [393]	Train-rmse:0.02255
# [394]	Train-rmse:0.02252
# [395]	Train-rmse:0.02244

# %%
#df_encoded_base.to_csv('base_2.csv', index=False, encoding='utf-8-sig')

# %% [markdown]
# # Prediccion

# %%
print(features)
# Out:
# ['Year', 'Month', 'Day', 'Nombre_Municipio_IPS2', 'MUNICIPIO', 'Day_Week', 'TENDENCIA', 'lag_1', 'mm_7', 'mm_12', 'lag_7', 'delta_lag', 'std_7', 'Nombre_Oficina_Arp_OFICINA BARRANQUILLA', 'Nombre_Oficina_Arp_OFICINA BOGOTA', 'Nombre_Oficina_Arp_OFICINA BUCARAMANGA', 'Nombre_Oficina_Arp_OFICINA CALI', 'Nombre_Oficina_Arp_OFICINA CARTAGENA', 'Nombre_Oficina_Arp_OFICINA MANIZALES', 'Nombre_Oficina_Arp_OFICINA MEDELLIN', 'Nombre_Oficina_Arp_OFICINA PEREIRA', 'Nombre_Tipo_Atencion_Arp_ALTA INMEDIATA', 'Nombre_Tipo_Atencion_Arp_AMBULATORIA', 'Nombre_Tipo_Atencion_Arp_HOSPITALARIA', 'Nombre_Tipo_Atencion_Arp_ODONTOLOGIA', 'Nombre_Tipo_Atencion_Arp_QUIRURGICO AMBULATORIO', 'Nombre_Tipo_Atencion_Arp_QUIRURGICO HOSPITALARIO', 'Nombre_Tipo_Atencion_Arp_UNIDAD DE CUIDADOS INTENSIVOS']

# %%
df_encoded_base = pd.read_csv('base_2.csv', encoding='utf-8-sig', low_memory=False)

# %%
df_encoded_base.head()
# Out:
#               Date  Year  Month  Day  Hour  Nombre_Municipio_IPS2  MUNICIPIO  \
# 7521029 2019-01-01  2019      1    1     0                     80        354
# 6131996 2019-01-01  2019      1    1     0                     80        684
# 6131995 2019-01-01  2019      1    1     0                     80        547
# 8925611 2019-01-01  2019      1    1     0                     97        659
# 8925610 2019-01-01  2019      1    1     0                     97        542
#
#          Cantidad  TENDENCIA  lag_1  ...  \
# 7521029         1          0    NaN  ...
# 6131996         1          0    1.0  ...
# 6131995         1          0    NaN  ...
# 8925611         1          0    1.0  ...
# 8925610         1          0    NaN  ...
#
#          Nombre_Oficina_Arp_OFICINA MANIZALES  \
# 7521029                                 False
# 6131996                                 False
# 6131995                                 False
# 8925611                                 False
# 8925610                                  True
#
#          Nombre_Oficina_Arp_OFICINA MEDELLIN  \
# 7521029                                False
# 6131996                                False
# 6131995                                 True
# 8925611                                False
# 8925610                                False
#
#          Nombre_Oficina_Arp_OFICINA PEREIRA  \
# 7521029                               False
# 6131996                               False
# 6131995                               False
# 8925611                                True
# 8925610                               False
#
#          Nombre_Tipo_Atencion_Arp_ALTA INMEDIATA  \
# 7521029                                    False
# 6131996                                    False
# 6131995                                    False
# 8925611                                    False
# 8925610                                    False
#
#          Nombre_Tipo_Atencion_Arp_AMBULATORIA  \
# 7521029                                 False
# 6131996                                 False
# 6131995                                 False
# 8925611                                 False
# 8925610                                 False
#
#          Nombre_Tipo_Atencion_Arp_HOSPITALARIA  \
# 7521029                                  False
# 6131996                                  False
# 6131995                                  False
# 8925611                                  False
# 8925610                                  False
#
#          Nombre_Tipo_Atencion_Arp_ODONTOLOGIA  \
# 7521029                                 False
# 6131996                                 False
# 6131995                                 False
# 8925611                                 False
# 8925610                                 False
#
#          Nombre_Tipo_Atencion_Arp_QUIRURGICO AMBULATORIO  \
# 7521029                                            False
# 6131996                                             True
# 6131995                                             True
# 8925611                                            False
# 8925610                                            False
#
#          Nombre_Tipo_Atencion_Arp_QUIRURGICO HOSPITALARIO  \
# 7521029                                              True
# 6131996                                             False
# 6131995                                             False
# 8925611                                              True
# 8925610                                              True
#
#          Nombre_Tipo_Atencion_Arp_UNIDAD DE CUIDADOS INTENSIVOS
# 7521029                                              False
# 6131996                                              False
# 6131995                                              False
# 8925611                                              False
# 8925610                                              False
#
# [5 rows x 31 columns]

# %%
fechas_2025 = pd.date_range(start="2025-01-01", end="2025-12-31", freq="D")

def generar_combinaciones(df):
    municipios = df["Nombre_Municipio_IPS2"].unique()
    oficinas = [col for col in df.columns if col.startswith("Nombre_Oficina_Arp_")]
    tipos_atencion = [col for col in df.columns if col.startswith("Nombre_Tipo_Atencion_Arp_")]
    return list(product(municipios, oficinas, tipos_atencion)), oficinas, tipos_atencion

def valores_fijos_promedio(df):
    return {
        "TENDENCIA": df["TENDENCIA"].mean(),
        "lag_1": df["lag_1"].mean(),
        "lag_7": df["lag_7"].mean(),
        "mm_7": df["mm_7"].mean(),
        "mm_12": df["mm_12"].mean(),
        "mm_30": df["mm_30"].mean(),
        "delta_lag": df["delta_lag"].mean(),
        "std_7": df["std_7"].mean(),
        "Hour": 0
    }

def predecir_combinacion(model, municipio, oficina_col, tipo_col, fechas, valores_fijos, X_cols, oficinas, tipos_atencion):
    df_temp = pd.DataFrame({
        "Date": fechas,
        "Year": fechas.year,
        "Month": fechas.month,
        "Day": fechas.day,
        "Hour": valores_fijos["Hour"],
        "Nombre_Municipio_IPS2": municipio,
        "MUNICIPIO": municipio,
    })

    # Agregar columnas fijas
    for col, val in valores_fijos.items():
        if col not in df_temp.columns:
            df_temp[col] = val

    # Inicializar todas las columnas dummy en 0
    for col in oficinas + tipos_atencion:
        df_temp[col] = 0

    # Activar la combinación actual
    df_temp[oficina_col] = 1
    df_temp[tipo_col] = 1

    # Reordenar columnas según el modelo
    X_pred = df_temp[X_cols]
    dmatrix = xgb.DMatrix(X_pred)

    # Realizar predicción
    df_temp["Pred_Cantidad"] = model.predict(dmatrix)

    # Agregar nombre descriptivo para oficina y tipo
    df_temp["Oficina"] = oficina_col.replace("Nombre_Oficina_Arp_", "")
    df_temp["Tipo_Atencion"] = tipo_col.replace("Nombre_Tipo_Atencion_Arp_", "")

    return df_temp[["Date", "Nombre_Municipio_IPS2", "Oficina", "Tipo_Atencion", "Pred_Cantidad"]]

# Paso 5: Función principal que corre todo en paralelo
def prediccion(df_base, model, n_jobs):
    combinaciones, oficinas, tipos_atencion = generar_combinaciones(df_base)
    valores_fijos = valores_fijos_promedio(df_base)
    X_cols = [col for col in df_base.columns if col not in ["Cantidad", "Date"]]

    resultados = Parallel(n_jobs=n_jobs)(
        delayed(predecir_combinacion)(model, municipio, oficina, tipo, fechas_2025, 
                                      valores_fijos, X_cols, oficinas, tipos_atencion)
        for municipio, oficina, tipo in combinaciones
    )

    return pd.concat(resultados, ignore_index=True)

# %%
df_pred = prediccion(df_encoded_base, model,n_jobs=15)

# %%
df_pred.head()
# Out:
#         Date  Nombre_Municipio_IPS2               Oficina   Tipo_Atencion  \
# 0 2025-01-01                     80  OFICINA BARRANQUILLA  ALTA INMEDIATA
# 1 2025-01-02                     80  OFICINA BARRANQUILLA  ALTA INMEDIATA
# 2 2025-01-03                     80  OFICINA BARRANQUILLA  ALTA INMEDIATA
# 3 2025-01-04                     80  OFICINA BARRANQUILLA  ALTA INMEDIATA
# 4 2025-01-05                     80  OFICINA BARRANQUILLA  ALTA INMEDIATA
#
#    Pred_Cantidad
# 0        0.99628
# 1        0.99628
# 2        0.99628
# 3        0.99628
# 4        0.99628

# %%
filas, columnas = df_pred.shape
print(f"Número de filas: {filas}")
print(f"Número de columnas: {columnas}")
# Out:
# Número de filas: 3331720
# Número de columnas: 5

# %%
df_pred.to_csv('prediccion_1.csv', inedex=False, encoding='utf-8')

# %% [markdown]
# # Resultado

# %%
df_label = df_pred.copy()

df_label['Nombre_Municipio_IPS2'] = df_label['Nombre_Municipio_IPS2'].map(municipio_ips_dict)

df_label.head()
# Out:
#         Date Nombre_Municipio_IPS2               Oficina   Tipo_Atencion  \
# 0 2025-01-01              MEDELLIN  OFICINA BARRANQUILLA  ALTA INMEDIATA
# 1 2025-01-02              MEDELLIN  OFICINA BARRANQUILLA  ALTA INMEDIATA
# 2 2025-01-03              MEDELLIN  OFICINA BARRANQUILLA  ALTA INMEDIATA
# 3 2025-01-04              MEDELLIN  OFICINA BARRANQUILLA  ALTA INMEDIATA
# 4 2025-01-05              MEDELLIN  OFICINA BARRANQUILLA  ALTA INMEDIATA
#
#    Pred_Cantidad
# 0        0.99628
# 1        0.99628
# 2        0.99628
# 3        0.99628
# 4        0.99628

# %%
df_pred_reco = df_label.copy()

# %%
Atencion = df_pred_reco['Tipo_Atencion'].value_counts().reset_index()
Atencion.columns = ['Tipo_Atencion NIT', 'Frecuencia']

print(Atencion)
# Out:
#                Tipo_Atencion NIT  Frecuencia
# 0                 ALTA INMEDIATA      475960
# 1                    AMBULATORIA      475960
# 2                   HOSPITALARIA      475960
# 3                    ODONTOLOGIA      475960
# 4         QUIRURGICO AMBULATORIO      475960
# 5        QUIRURGICO HOSPITALARIO      475960
# 6  UNIDAD DE CUIDADOS INTENSIVOS      475960

# %%
df_pred_reco.columns
# Out:
# Index(['Date', 'Nombre_Municipio_IPS2', 'Oficina', 'Tipo_Atencion',
#        'Pred_Cantidad'],
#       dtype='object')

# %%
df_pred_reco = df_pred_reco[['Date', 'Year', 'Month', 'Day', 'Day_Week', 'TENDENCIA', 
                             'Nombre_Oficina_Arp', 'Nombre_Municipio_IPS2', 'Municipio', 
                             'Nombre_Tipo_Atencion_Arp', 'Cantidad']]

df_pred_reco.head()
# Out:
#         Date  Year  Month  Day  Day_Week  TENDENCIA Nombre_Oficina_Arp  \
# 0 2025-01-01  2025      1    1         2       2192   OFICINA MEDELLIN
# 1 2025-01-02  2025      1    2         3       2193   OFICINA MEDELLIN
# 2 2025-01-03  2025      1    3         4       2194   OFICINA MEDELLIN
# 3 2025-01-04  2025      1    4         5       2195   OFICINA MEDELLIN
# 4 2025-01-05  2025      1    5         6       2196     OFICINA BOGOTA
#
#   Nombre_Municipio_IPS2 Municipio Nombre_Tipo_Atencion_Arp  Cantidad
# 0              MEDELLIN    BOGOTA              AMBULATORIA  1.000272
# 1              MEDELLIN    BOGOTA              AMBULATORIA  1.000272
# 2              MEDELLIN    BOGOTA              AMBULATORIA  1.000272
# 3              MEDELLIN    BOGOTA              AMBULATORIA  1.002856
# 4              MEDELLIN    BOGOTA              AMBULATORIA  0.998839

# %%
df_pred_reco.to_csv('prediccion_reco.csv', index=False, encoding='utf-8')

# %% [markdown]
# ## Grafica

# %% [markdown]
# ### Diaria

# %%
# Asegurar tipo datetime
df_pred_reco['Date'] = pd.to_datetime(df_pred_reco['Date'])

# Agrupar por fecha
media_diaria = df_pred_reco.groupby('Date')['Pred_Cantidad'].mean().reset_index()

# Gráfico
plt.figure(figsize=(14, 5))
sns.lineplot(data=media_diaria, x='Date', y='Pred_Cantidad')
plt.title('Cantidad Promedio por Día')
plt.xlabel('Fecha')
plt.ylabel('Cantidad Promedio')
plt.tight_layout()
plt.show()

# %%
frecuencia_tipo_diaria = df_pred_reco.groupby(['Date', 'Tipo_Atencion']).size().reset_index(name='Frecuencia')

plt.figure(figsize=(14, 5))
sns.lineplot(data=frecuencia_tipo_diaria, x='Date', y='Frecuencia', hue='Tipo_Atencion')
plt.title('Frecuencia Diaria por Tipo de Atención')
plt.xlabel('Fecha')
plt.ylabel('Frecuencia')
plt.legend(title='Tipo de Atención', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
frecuencia_oficina_diaria = df_pred_reco.groupby(['Date', 'Oficina']).size().reset_index(name='Frecuencia')

plt.figure(figsize=(14, 5))
sns.lineplot(data=frecuencia_oficina_diaria, x='Date', y='Frecuencia', hue='Oficina')
plt.title('Frecuencia Diaria por Oficina')
plt.xlabel('Fecha')
plt.ylabel('Frecuencia')
plt.legend(title='Oficina', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Mensual

# %%
# Asegurar que la columna de fecha es datetime
df_pred_reco['Date'] = pd.to_datetime(df_pred_reco['Date'])

# Crear columna año-mes
df_pred_reco['AñoMes'] = df_pred_reco['Date'].dt.to_period('M')

# Agrupar y calcular la media mensual
media_mensual = df_pred_reco.groupby('AñoMes')['Pred_Cantidad'].mean().reset_index()
media_mensual['AñoMes'] = media_mensual['AñoMes'].astype(str)

# Gráfico
plt.figure(figsize=(12, 5))
sns.lineplot(data=media_mensual, x='AñoMes', y='Pred_Cantidad', marker='o')
plt.title('Cantidad Promedio por Mes')
plt.xlabel('Mes')
plt.ylabel('Cantidad Promedio')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
frecuencia_tipo = df_pred_reco['Tipo_Atencion_Arp'].value_counts().reset_index()
frecuencia_tipo.columns = ['Tipo de Atención', 'Frecuencia']

plt.figure(figsize=(10, 5))
sns.barplot(data=frecuencia_tipo, x='Tipo de Atención', y='Frecuencia')
plt.title('Frecuencia por Tipo de Atención')
plt.xlabel('Tipo de Atención')
plt.ylabel('Frecuencia')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
frecuencia_oficina = df_pred_reco['Nombre_Oficina_Arp'].value_counts().reset_index()
frecuencia_oficina.columns = ['Oficina', 'Frecuencia']

plt.figure(figsize=(10, 5))
sns.barplot(data=frecuencia_oficina, x='Oficina', y='Frecuencia')
plt.title('Frecuencia por Oficina')
plt.xlabel('Oficina')
plt.ylabel('Frecuencia')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
